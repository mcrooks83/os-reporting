# %% [markdown]
# ### Notebook to compute statistics

# %% [markdown]
# #### Create a data set for each pre assigned group

# %%
import helpers as h
import pandas as pd
import numpy as np

# %%
metrics = h.read_csv_to_data_frame("clustered_patient_metrics.csv")

# %%
# create a data set for group 0 pre op
grp_0 = metrics[metrics['Group'] == 0]
grp_1 = metrics[metrics['Group'] == 1]
grp_2 = metrics[metrics['Group'] == 2]

# %%
# statistics
def calculate_statistics_for_data_frame(df, title):
    df = df.drop(["Group", "patient_number"], axis=1)
    mean_values = df.mean()
    std_values = df.std()
    _max = df.max() 
    _min = df.min()
    range_values = df.max() - df.min()
    
    # Combine them into a DataFrame for better visibility
    summary_stats = pd.DataFrame({
        'Mean': mean_values,
        'Std': std_values,
        'max': _max,
        'min': _min,
        'Range': range_values
    })
    summary_stats.index.name = title

    return summary_stats

# %%
grp_0_stats = calculate_statistics_for_data_frame(grp_0, "Group 0")
grp_0_stats
# Out:
# left_avg_load            4.18
# right_avg_load           4.19
# overall_load             4.19
# load_in_left            50.29
# load_in_right           52.88
# imbalance                5.76
# left_x_avg_load          4.62
# left_y_avg_load          3.38
# left_z_avg_load          6.65
# left_x_contribution     48.00
# left_y_contribution     31.00
# left_z_contribution     48.00
# right_x_avg_load         4.61
# right_y_avg_load         3.36
# right_z_avg_load         4.98
# right_x_contribution    45.00
# right_y_contribution    26.00
# right_z_contribution    45.00
# v_imbalance             12.86
# ml_imbalance             6.64
# ap_imbalance            25.60
# actual_group             3.00
# dtype: float64
#                            Mean       Std    max    min  Range
# Group 0
# left_avg_load          3.570000  0.431200   4.18   2.73   1.45
# right_avg_load         3.735714  0.501958   4.19   2.73   1.46
# overall_load           3.651429  0.458855   4.19   2.73   1.46
# load_in_left          48.917143  1.204156  50.29  47.12   3.17
# load_in_right         51.082857  1.204156  52.88  49.71   3.17
# imbalance              2.331429  2.220476   5.76   0.00   5.76
# left_x_avg_load        3.647143  0.571743   4.62   2.82   1.80
# left_y_avg_load        2.145714  0.706018   3.38   1.30   2.08
# left_z_avg_load        3.810000  1.481643   6.65   2.02   4.63
# left_x_contribution   38.857143  5.727960  48.00  33.00  15.00
# left_y_contribution   22.285714  4.423961  31.00  18.00  13.00
# left_z_contribution   38.714286  5.407226  48.00  33.00  15.00
# right_x_avg_load       4.040000  0.590960   4.61   2.82   1.79
# right_y_avg_load       2.058571  0.639673   3.36   1.45   1.91
# right_z_avg_load       4.137143  0.876179   4.98   2.78   2.20
# right_x_contribution  39.714286  2.927700  45.00  36.00   9.00
# right_y_contribution  19.857143  3.184785  26.00  17.00   9.00
# right_z_contribution  40.285714  3.039424  45.00  37.00   8.00
# v_imbalance            6.242857  4.267746  12.86   0.00  12.86
# ml_imbalance           4.462857  2.424800   6.64   0.30   6.34
# ap_imbalance          13.517143  6.681910  25.60   3.40  22.20
# actual_group           1.000000  1.154701   3.00   0.00   3.00

# %%
grp_1_stats = calculate_statistics_for_data_frame(grp_1, "Group 1")
grp_1_stats
# Out:
#                            Mean       Std  \
# Group 1
# left_avg_load          3.508571  0.910008
# right_avg_load         3.577143  0.983340
# overall_load           3.545714  0.939323
# load_in_left          49.615714  1.797107
# load_in_right         50.384286  1.797107
# imbalance              2.894286  1.958187
# left_x_avg_load        3.515714  0.617248
# left_y_avg_load        2.062857  0.271767
# left_z_avg_load        4.990000  0.962046
# left_x_contribution   33.428571  4.237025
# left_y_contribution   19.571429  1.133893
# left_z_contribution   47.142857  3.387653
# right_x_avg_load       3.667143  0.559336
# right_y_avg_load       3.017143  0.757534
# right_z_avg_load       4.734286  1.133473
# right_x_contribution  32.285714  4.191829
# right_y_contribution  26.428571  4.577377
# right_z_contribution  41.428571  7.207800
# v_imbalance            4.502857  3.135462
# ml_imbalance          18.962857  9.590700
# ap_imbalance           4.151429  3.812363
# actual_group           1.285714  1.112697
#
#                                                                 max-min  Range
# Group 1
# left_avg_load         (left_avg_load            5.17\nright_avg_load...   2.57
# right_avg_load        (left_avg_load            5.17\nright_avg_load...   3.02
# overall_load          (left_avg_load            5.17\nright_avg_load...   2.79
# load_in_left          (left_avg_load            5.17\nright_avg_load...   5.40
# load_in_right         (left_avg_load            5.17\nright_avg_load...   5.40
# imbalance             (left_avg_load            5.17\nright_avg_load...   5.68
# left_x_avg_load       (left_avg_load            5.17\nright_avg_load...   1.83
# left_y_avg_load       (left_avg_load            5.17\nright_avg_load...   0.79
# left_z_avg_load       (left_avg_load            5.17\nright_avg_load...   2.60
# left_x_contribution   (left_avg_load            5.17\nright_avg_load...  11.00
# left_y_contribution   (left_avg_load            5.17\nright_avg_load...   3.00
# left_z_contribution   (left_avg_load            5.17\nright_avg_load...  10.00
# right_x_avg_load      (left_avg_load            5.17\nright_avg_load...   1.46
# right_y_avg_load      (left_avg_load            5.17\nright_avg_load...   2.17
# right_z_avg_load      (left_avg_load            5.17\nright_avg_load...   2.75
# right_x_contribution  (left_avg_load            5.17\nright_avg_load...  12.00
# right_y_contribution  (left_avg_load            5.17\nright_avg_load...  13.00
# right_z_contribution  (left_avg_load            5.17\nright_avg_load...  21.00
# v_imbalance           (left_avg_load            5.17\nright_avg_load...   8.00
# ml_imbalance          (left_avg_load            5.17\nright_avg_load...  27.12
# ap_imbalance          (left_avg_load            5.17\nright_avg_load...   9.92
# actual_group          (left_avg_load            5.17\nright_avg_load...   3.00

# %%
grp_2_stats = calculate_statistics_for_data_frame(grp_2, "Group 2")
grp_2_stats
# Out:
#                          Mean       Std  Range
# Group 2
# left_avg_load          4.2450  0.390342   0.86
# right_avg_load         4.0550  0.645265   1.48
# overall_load           4.1500  0.490034   1.12
# load_in_left          51.3200  2.771221   5.63
# load_in_right         48.6800  2.771221   5.63
# imbalance              4.7000  3.249328   7.14
# left_x_avg_load        4.3175  0.583517   1.37
# left_y_avg_load        3.2475  1.027469   2.45
# left_z_avg_load        4.1250  0.614139   1.18
# left_x_contribution   37.0000  2.309401   4.00
# left_y_contribution   27.0000  4.242641  10.00
# left_z_contribution   35.5000  3.000000   6.00
# right_x_avg_load       4.2075  0.398361   0.90
# right_y_avg_load       2.4650  0.375100   0.75
# right_z_avg_load       5.5100  0.603048   1.37
# right_x_contribution  34.5000  1.290994   3.00
# right_y_contribution  20.7500  3.862210   8.00
# right_z_contribution  45.2500  3.304038   7.00
# v_imbalance            2.6400  1.711140   3.96
# ml_imbalance          20.7600  2.540341   6.08
# ap_imbalance          14.5200  6.363374  15.46
# actual_group           1.0000  0.816497   2.00

# %%
# view key metrics

metrics_to_view = ["overall_load", "ml_imbalance", ] #left_y_avg_load", "right_y_avg_load"]

key_grp_0 = grp_0_stats.loc[metrics_to_view]
key_grp_1 = grp_1_stats.loc[metrics_to_view]
key_grp_2 = grp_2_stats.loc[metrics_to_view]


print(f"{key_grp_0}, num of patients: {grp_0.shape[0]}")
print()
print(f"{key_grp_1}, num of patients: {grp_1.shape[0]}")
print()
print(f"{key_grp_2}, num of patients: {grp_2.shape[0]}")
# Out:
#                   Mean       Std  Range
# Group 0
# overall_load  3.651429  0.458855   1.46
# ml_imbalance  4.462857  2.424800   6.34, num of patients: 7
#
#                    Mean       Std  Range
# Group 1
# overall_load   3.545714  0.939323   2.79
# ml_imbalance  18.962857  9.590700  27.12, num of patients: 7
#
#                Mean       Std  Range
# Group 2
# overall_load   4.15  0.490034   1.12
# ml_imbalance  20.76  2.540341   6.08, num of patients: 4
